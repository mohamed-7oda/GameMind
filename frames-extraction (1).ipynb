# %%
# !pip install SoccerNet
# !pip uninstall wandb -y

import SoccerNet
from SoccerNet.Downloader import SoccerNetDownloader
import os
import numpy as np
import pandas as pd
from IPython.display import Image
import cv2
from glob import glob
import re
import yaml
# Out:
# Requirement already satisfied: SoccerNet in /usr/local/lib/python3.11/dist-packages (0.1.62)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from SoccerNet) (4.67.1)
# Requirement already satisfied: scikit-video in /usr/local/lib/python3.11/dist-packages (from SoccerNet) (1.1.11)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from SoccerNet) (3.9.2)
# Requirement already satisfied: google-measurement-protocol in /usr/local/lib/python3.11/dist-packages (from SoccerNet) (1.1.0)
# Requirement already satisfied: pycocoevalcap in /usr/local/lib/python3.11/dist-packages (from SoccerNet) (1.2)
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.11/dist-packages (from SoccerNet) (1.0.0rc2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.11/dist-packages (from SoccerNet) (1.40.39)
# Requirement already satisfied: botocore<1.41.0,>=1.40.39 in /usr/local/lib/python3.11/dist-packages (from boto3->SoccerNet) (1.40.39)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3->SoccerNet) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from boto3->SoccerNet) (0.14.0)
# Requirement already satisfied: requests<3.0a0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from google-measurement-protocol->SoccerNet) (2.32.5)
# Requirement already satisfied: prices>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from google-measurement-protocol->SoccerNet) (1.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (6.0.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (0.28.1)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (0.19.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (1.1.10)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (0.3.4)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]->SoccerNet) (1.5.4)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet) (3.0.51)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SoccerNet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SoccerNet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SoccerNet) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SoccerNet) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SoccerNet) (1.26.4)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SoccerNet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SoccerNet) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->SoccerNet) (2.9.0.post0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from pycocoevalcap->SoccerNet) (2.0.10)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from scikit-video->SoccerNet) (1.15.3)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.41.0,>=1.40.39->boto3->SoccerNet) (2.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[cli]->SoccerNet) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[cli]->SoccerNet) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[cli]->SoccerNet) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->huggingface_hub[cli]->SoccerNet) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub[cli]->SoccerNet) (0.16.0)
# Requirement already satisfied: babel>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from prices>=1.0.0->google-measurement-protocol->SoccerNet) (2.17.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->SoccerNet) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0a0,>=2.0->google-measurement-protocol->SoccerNet) (3.4.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer-slim->huggingface_hub[cli]->SoccerNet) (8.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]->SoccerNet) (0.2.13)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub[cli]->SoccerNet) (1.3.1)
# WARNING: Skipping wandb as it is not installed.

# %%
# !pip uninstall -y numpy
# !rm -rf /usr/local/lib/python3.11/dist-packages/numpy*
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4

# %%
# !pip install numpy==1.26.4 matplotlib==3.9.2 ultralytics==8.3.33
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: matplotlib==3.9.2 in /usr/local/lib/python3.11/dist-packages (3.9.2)
# Requirement already satisfied: ultralytics==8.3.33 in /usr/local/lib/python3.11/dist-packages (8.3.33)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (4.11.0.86)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (7.1.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (2.0.17)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics==8.3.33) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics==8.3.33) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.3.33) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.3.33) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.3.33) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.3.33) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.3.33) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.33) (3.0.2)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.3 which is incompatible.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# transformers 4.53.3 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 1.0.0rc2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
import os, sys
os.kill(os.getpid(), 9)
# Run it again

# %%
yolo_base = '/kaggle/working/yolov8'
sn_track_base = '/tmp/tracking'

# %%
# !mkdir -p $sn_track_base
# !touch $sn_track_base/test.zip
# !touch $sn_track_base/challenge.zip

mySoccerNetDownloader=SoccerNetDownloader(LocalDirectory="/tmp/")
mySoccerNetDownloader.downloadDataTask(task="tracking", split=["train", "test", "challenge"])
# !unzip -q -d $sn_track_base $sn_track_base/train.zip
# Out:
# Downloading /tmp/tracking/train.zip...: : 9.58GiB [08:28, 18.8MiB/s]
# /tmp/tracking/test.zip already exists
# /tmp/tracking/challenge.zip already exists

# %%
# Of the 57 half , 50 are used for training and 7 for validation.
trn_dirs = sorted(glob(f'{sn_track_base}/train/SNMOT*'))
#tst_dirs = sorted(glob(f'{sn_track_base}/test/SNMOT*'))
tst_dirs = trn_dirs[50:]
trn_dirs = trn_dirs[:50]

debug=True
if debug:
    trn_dirs = trn_dirs[:5]
    tst_dirs = tst_dirs[:5]

split_dirs = {
    'train':trn_dirs,
    'valid':tst_dirs
}

# ４ types of labels are used.
# labels = ['ball', 'player', 'referee', 'goalkeepers']
# label_dict = {'ball': 0, 'player': 1, 'referee': 2, 'goalkeeper': 3, 'goalkeepers': 3}
labels = ['player team left', 'player team right', 'goalkeepers team left', 'goalkeeper team right', 'referee', 'ball']
label_dict = {'player team left' : 0, 'player team right' : 1, 'goalkeepers team left' : 2, 'goalkeeper team right' : 3, 'referee' : 4, 'ball' : 5}

# %%
#(1) image file path
yolo_train_img_dir = f'{yolo_base}/images/train'
yolo_valid_img_dir = f'{yolo_base}/images/valid'

#(2) label file path
yolo_train_label_dir = f'{yolo_base}/labels/train'
yolo_valid_label_dir = f'{yolo_base}/labels/valid'

#(3) config file path
yaml_file = f'{yolo_base}/data.yaml'

#!rm -rf /home/tito/kaggle/dfl-bundesliga-data-shootout/work/yolov5
os.makedirs(yolo_train_img_dir, exist_ok=True)
os.makedirs(yolo_valid_img_dir, exist_ok=True)
os.makedirs(yolo_train_label_dir, exist_ok=True)
os.makedirs(yolo_valid_label_dir, exist_ok=True)

# %%
# convert from x,y,w,h to yolo format
def get_yolo_format_bbox(img_w, img_h, box):
    w = box[2]
    h = box[3]
    xc = box[0] + int(np.round(w/2))
    yc = box[1] + int(np.round(h/2))
    box = [xc/img_w, yc/img_h, w/img_w, h/img_h]
    box = [f"{i:.4g}" for i in box]
    return box

# %%
def get_info(info):
    results = []
    for line in open(info):
        # Match the tracklet ID and capture the full label after '='
        m = re.match(r'trackletID_(\d+)=\s*(.*)', line.strip())
        if m:
            # Extract the full label and split by ';' to get the first part
            label = m.group(2).split(";")[0].strip()
            if label not in label_dict:
                print('bad label:', label)  # Debugging for unmatched labels
                continue 
            # Append the ID and label to the results
            results.append([m.group(1), label])
            print("Processed:", results)  # Debugging processed results
    # Convert results to a DataFrame and return as a dictionary
    return pd.DataFrame(results, columns=['id', 'lbl']).set_index('id').to_dict()['lbl']

# %%
# make image simlink and label files
for split in split_dirs:
    if split == 'train':
        yolo_img_dir = yolo_train_img_dir
        yolo_label_dir = yolo_train_label_dir
    else:
        yolo_img_dir = yolo_valid_img_dir
        yolo_label_dir = yolo_valid_label_dir
        
    for this_dir in split_dirs[split]:
        print('this_dir:',this_dir)
        video = this_dir.split('/')[-1]
        info = this_dir + '/gameinfo.ini'
        det = this_dir + '/gt/gt.txt'
        info_dict = get_info(info)
        det_df = pd.read_csv(det, names=['frame','player','x','y','w','h','f1','f2','f3','f4'], usecols=['frame','player','x','y','w','h'])
        det_df['label'] = det_df.player.astype(str).map(info_dict)
        det_df['label_id'] = det_df['label'].map(label_dict)
        # check
        ng_list = list(det_df[det_df.label_id.isnull()].label.unique())
        if len(ng_list)>0:
            #print('ng_list:',ng_list, det_df.dropna().shape, det_df.shape)
            det_df = det_df.dropna()
        for grp, grp_df in det_df.groupby('frame'):
            frame = f'{grp:06}'
            img_file = f'{this_dir}/img1/{frame}.jpg'
            dst_file = f'{yolo_img_dir}/{video}_{frame}.jpg'
            if not os.path.exists(dst_file):
                os.symlink(img_file, dst_file)
                #print(img_file)
            img = cv2.imread(dst_file)
            height, width, _ = img.shape 
            bboxes = []
            for arr in grp_df[['x', 'y', 'w', 'h', 'label_id']].values:
                box = get_yolo_format_bbox(width, height, arr[:4])
                bboxes.append([arr[4]]+box)
            file_name = f'{yolo_label_dir}/{video}_{frame}.txt'
            with open(file_name, 'w') as f:
                for i, bbox in enumerate(bboxes):
                    bbox = [str(i) for i in bbox]
                    str_bbox = ' '.join(bbox)
                    f.write(str_bbox)
                    f.write('\n')
# Out:
# this_dir: /tmp/tracking/train/SNMOT-060
# Processed: [['1', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball'], ['19', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball'], ['19', 'player team left'], ['20', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball'], ['19', 'player team left'], ['20', 'player team left'], ['21', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball'], ['19', 'player team left'], ['20', 'player team left'], ['21', 'player team left'], ['22', 'goalkeepers team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball'], ['19', 'player team left'], ['20', 'player team left'], ['21', 'player team left'], ['22', 'goalkeepers team left'], ['23', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball'], ['19', 'player team left'], ['20', 'player team left'], ['21', 'player team left'], ['22', 'goalkeepers team left'], ['23', 'player team right'], ['24', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball'], ['19', 'player team left'], ['20', 'player team left'], ['21', 'player team left'], ['22', 'goalkeepers team left'], ['23', 'player team right'], ['24', 'player team right'], ['25', 'goalkeeper team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team right'], ['5', 'player team right'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'referee'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'referee'], ['18', 'ball'], ['19', 'player team left'], ['20', 'player team left'], ['21', 'player team left'], ['22', 'goalkeepers team left'], ['23', 'player team right'], ['24', 'player team right'], ['25', 'goalkeeper team right'], ['26', 'referee']]
# this_dir: /tmp/tracking/train/SNMOT-061
# Processed: [['1', 'ball']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left'], ['20', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left'], ['20', 'player team right'], ['21', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'player team left'], ['24', 'player team left']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'player team left'], ['24', 'player team left'], ['25', 'goalkeeper team right']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'player team left'], ['24', 'player team left'], ['25', 'goalkeeper team right'], ['26', 'referee']]
# Processed: [['1', 'ball'], ['2', 'goalkeepers team left'], ['3', 'referee'], ['4', 'referee'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'player team right'], ['16', 'player team left'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team left'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'player team left'], ['24', 'player team left'], ['25', 'goalkeeper team right'], ['26', 'referee'], ['27', 'ball']]
# this_dir: /tmp/tracking/train/SNMOT-062
# Processed: [['1', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'goalkeeper team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'goalkeeper team right'], ['18', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'goalkeeper team right'], ['18', 'referee'], ['19', 'ball']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'goalkeeper team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'goalkeeper team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'goalkeeper team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team left'], ['22', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'goalkeeper team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team left'], ['22', 'player team left'], ['23', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team right'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team right'], ['10', 'player team right'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team left'], ['15', 'player team left'], ['16', 'player team left'], ['17', 'goalkeeper team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team left'], ['22', 'player team left'], ['23', 'referee'], ['24', 'player team left']]
# this_dir: /tmp/tracking/train/SNMOT-063
# Processed: [['1', 'goalkeepers team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'referee']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'referee'], ['19', 'ball']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'player team right']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'player team right'], ['24', 'player team left']]
# Processed: [['1', 'goalkeepers team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team right'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'referee'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team left'], ['12', 'player team left'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'referee'], ['19', 'ball'], ['20', 'player team right'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'player team right'], ['24', 'player team left'], ['25', 'goalkeeper team right']]
# this_dir: /tmp/tracking/train/SNMOT-064
# Processed: [['1', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team right'], ['20', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'referee'], ['22', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'referee'], ['22', 'referee'], ['23', 'ball']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team left'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team right'], ['18', 'player team right'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'referee'], ['22', 'referee'], ['23', 'ball'], ['24', 'goalkeepers team left']]
# this_dir: /tmp/tracking/train/SNMOT-164
# Processed: [['1', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'goalkeepers team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'goalkeepers team left'], ['4', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'goalkeepers team left'], ['4', 'referee'], ['5', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'goalkeepers team left'], ['4', 'referee'], ['5', 'referee'], ['6', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'goalkeepers team left'], ['4', 'referee'], ['5', 'referee'], ['6', 'player team right'], ['7', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'goalkeepers team left'], ['4', 'referee'], ['5', 'referee'], ['6', 'player team right'], ['7', 'player team left'], ['8', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'goalkeepers team left'], ['4', 'referee'], ['5', 'referee'], ['6', 'player team right'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'goalkeepers team left'], ['4', 'referee'], ['5', 'referee'], ['6', 'player team right'], ['7', 'player team left'], ['8', 'player team left'], ['9', 'player team right'], ['10', 'player team left']]
# ...
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'goalkeeper team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'goalkeeper team right'], ['22', 'player team right']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'goalkeeper team right'], ['22', 'player team right'], ['23', 'player team left']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'goalkeeper team right'], ['22', 'player team right'], ['23', 'player team left'], ['24', 'referee']]
# Processed: [['1', 'player team left'], ['2', 'player team left'], ['3', 'player team left'], ['4', 'player team left'], ['5', 'player team right'], ['6', 'referee'], ['7', 'player team left'], ['8', 'ball'], ['9', 'player team left'], ['10', 'player team left'], ['11', 'player team right'], ['12', 'player team right'], ['13', 'player team right'], ['14', 'player team right'], ['15', 'player team right'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team right'], ['21', 'goalkeeper team right'], ['22', 'player team right'], ['23', 'player team left'], ['24', 'referee'], ['25', 'ball']]
# this_dir: /tmp/tracking/train/SNMOT-168
# Processed: [['1', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee'], ['16', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee'], ['16', 'player team right'], ['17', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team left']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team left'], ['21', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team left'], ['21', 'player team right'], ['22', 'player team right']]
# Processed: [['1', 'player team right'], ['2', 'player team left'], ['3', 'player team right'], ['4', 'player team left'], ['5', 'player team left'], ['6', 'player team right'], ['7', 'player team right'], ['8', 'player team right'], ['9', 'player team left'], ['10', 'player team right'], ['11', 'referee'], ['12', 'ball'], ['13', 'player team left'], ['14', 'player team left'], ['15', 'referee'], ['16', 'player team right'], ['17', 'player team left'], ['18', 'player team left'], ['19', 'player team right'], ['20', 'player team left'], ['21', 'player team right'], ['22', 'player team right'], ['23', 'goalkeeper team right']]

# %%
# Dump config file
data_yaml = dict(
    train = yolo_train_img_dir,
    val = yolo_valid_img_dir,
    nc = 6,
    names = labels
)

with open(yaml_file, 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=True)

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
# !pip install ultralytics==8.3.33
# Out:
# Requirement already satisfied: ultralytics==8.3.33 in /usr/local/lib/python3.11/dist-packages (8.3.33)
# Collecting numpy>=1.23.0 (from ultralytics==8.3.33)
#   Downloading numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (7.1.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.33) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.33) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.33) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.33) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.33) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.33) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.33) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.33) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics==8.3.33) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics==8.3.33) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.3.33) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.3.33) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.3.33) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics==8.3.33) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics==8.3.33) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.3.33) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.3.33) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.33) (3.0.2)
# Downloading numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 94.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.3.4 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.3 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.4 which is incompatible.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.3.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# transformers 4.53.3 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 1.0.0rc2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed numpy-2.3.4

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.33 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6538.4/8062.4 GB disk)

# %%
from IPython import display
display.clear_output()

# %%
# !pip uninstall -y ray
# Out:
# Found existing installation: ray 2.49.2
# Uninstalling ray-2.49.2:
#   Successfully uninstalled ray-2.49.2

# %%
# !pip install scikit-learn --upgrade --force-reinstall
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting numpy>=1.22.0 (from scikit-learn)
#   Using cached numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.3 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 77.7 MB/s eta 0:00:00:00:010:01
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 18.4 MB/s eta 0:00:00
# Using cached numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 52.2 MB/s eta 0:00:00:00:0100:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.2
#     Uninstalling joblib-1.5.2:
#       Successfully uninstalled joblib-1.5.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.3.4 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.16.2 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.4 which is incompatible.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.3.4 which is incompatible.
# ydata-profiling 4.17.0 requires scipy<1.16,>=1.4.1, but you have scipy 1.16.2 which is incompatible.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.7.2 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.2 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# transformers 4.53.3 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 1.0.0rc2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed joblib-1.5.2 numpy-2.3.4 scikit-learn-1.7.2 scipy-1.16.2 threadpoolctl-3.6.0

# %%
yaml_file = '/kaggle/working/yolov8/data.yaml'
# !yolo task=detect mode=train model=yolov8x.pt data={yaml_file} epochs=50 imgsz=600 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.221 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.33 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8x.pt, data=/kaggle/working/yolov8/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=600, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761334264.368153     329 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761334264.373210     329 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8723746  ultralytics.nn.modules.head.Detect           [6, [320, 640, 640]]
# Model summary: 365 layers, 68,158,386 parameters, 68,158,370 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[600] must be multiple of max stride 32, updating to [608]
# train: Scanning /kaggle/working/yolov8/labels/train.cache... 3750 images, 0 back
# /usr/local/lib/python3.11/dist-packages/ultralytics/data/augment.py:1850: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/yolov8/labels/valid.cache... 3750 images, 0 backgr
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 608 train, 608 val
# Using 2 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50        12G      1.466      2.293     0.9307        564        608:

# %%
# Define the path to your configuration file
yaml_file = '/kaggle/working/yolov8/data.yaml'

# Define the path to your last saved weights
# We use 'last.pt' to resume training from exactly where it left off
resume_weights = 'runs/detect/train2/weights/last.pt'

# Run the training command
# -- 'resume=True' tells YOLO to continue from the 'resume_weights' checkpoint
# -- 'epochs=50' sets the *total* number of epochs. Since 2 are done, it will run 48 more.
# !yolo task=detect mode=train resume=True model=$resume_weights data={yaml_file} epochs=50 imgsz=600 plots=True

# %%
# predict!
# Make sure tst_dirs is defined from your previous data setup
check_images = f'{tst_dirs[0]}/img1' 

# ⬇️ *** This is the corrected path *** ⬇️
weight_file = 'runs/detect/train2/weights/best.pt' 

# !yolo task=detect mode=predict model=$weight_file source=$check_images save=True
# Out:
# Ultralytics 8.3.33 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 68,129,346 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/750 /tmp/tracking/train/SNMOT-164/img1/000001.jpg: 352x608 5 player team lefts, 1 player team right, 1 goalkeeper team right, 6 referees, 1 ball, 66.1ms
# image 2/750 /tmp/tracking/train/SNMOT-164/img1/000002.jpg: 352x608 5 player team lefts, 2 goalkeeper team rights, 3 referees, 1 ball, 56.0ms
